# %% [markdown]
# <a href="https://colab.research.google.com/github/Sockcave/GGWP/blob/main/dota2_feature_sentiment_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Feature Engineering**##
# Early stages.

# %%
pip install boto3
# Out:
# ...
#      |████████████████████████████████| 133kB 2.6MB/s
# ...
#      |████████████████████████████████| 6.7MB 4.3MB/s
# ...
#      |████████████████████████████████| 71kB 6.0MB/s
# ...
#      |████████████████████████████████| 133kB 47.1MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
pip install -U textblob
# Out:
# Requirement already up-to-date: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from textblob import TextBlob

# %%
eng = pd.read_csv('eng_chat.csv')
eng = eng.iloc[:, 2:6]
eng.head()
# Out:
#    match        time  slot                                text
# 0      0  1808.40822     9                                100%
# 1      1  -131.14018     0              twitch.tv/rage_channel
# 2      1  -121.60481     0  https://www.twitch.tv/rage_channel
# 3      1   700.72893     0  https://www.twitch.tv/rage_channel
# 4      1   702.99503     0  https://www.twitch.tv/rage_channel

# %% [markdown]
# ##**Testing Features**##

# %%
# Text Length as Feature
eng['text length'] = [len(text) for text in eng['text']]
eng.head()
# Out:
#    match        time  slot                                text  text length
# 0      0  1808.40822     9                                100%            4
# 1      1  -131.14018     0              twitch.tv/rage_channel           22
# 2      1  -121.60481     0  https://www.twitch.tv/rage_channel           34
# 3      1   700.72893     0  https://www.twitch.tv/rage_channel           34
# 4      1   702.99503     0  https://www.twitch.tv/rage_channel           34

# %% [markdown]
# ##**Polarity and Subjectivity**##
# * Using TextBlob rn
# * Sentiment Analysis (Opinion Mining): technique that detects polarity (positive, neutral, or negative)
# * Subjectivity refers to the extent the text is stating a fact or an opinion/personal feeling.

# %%
eng['polarity'] = eng['text'].apply(lambda x: TextBlob(x).sentiment[0])
eng['subjectivity'] = eng['text'].apply(lambda x: TextBlob(x).sentiment[1])
display(eng.sort_values('polarity', ascending=False).head(10), 
        eng.sort_values('polarity', ascending=False).tail(10))
# Out:
#           match        time  slot  ... text length  polarity  subjectivity
# 4888913  705886  1304.94807     1  ...          16       1.0           1.0
# 2365847  340455  2983.59193     0  ...          22       1.0           1.0
# 4393711  634746  1276.32165     1  ...          17       1.0           0.9
# 396691    57291  2148.48160     7  ...          10       1.0           1.0
# 1148585  165852  2819.14568     9  ...           2       1.0           1.0
# 2366020  340482  2032.54523     9  ...          11       1.0           0.3
# 2365997  340478  2240.07347     5  ...          34       1.0           1.0
# 4736492  684068  1303.38177     2  ...          49       1.0           1.0
# 5092926  734987  2123.57270     2  ...          28       1.0           1.0
# 2365912  340462  1057.64180     4  ...           4       1.0           0.3
#
# [10 rows x 7 columns]
#           match        time  slot  ... text length  polarity  subjectivity
# ...

# %%
eng_with_features_one = eng.copy(deep = True)

# %%
eng_with_features_one
# Out:
#           match        time  slot  ... text length  polarity  subjectivity
# 0             0  1808.40822     9  ...           4       0.0           0.0
# 1             1  -131.14018     0  ...          22       0.0           0.0
# 2             1  -121.60481     0  ...          34       0.0           0.0
# 3             1   700.72893     0  ...          34       0.0           0.0
# 4             1   702.99503     0  ...          34       0.0           0.0
# ...         ...         ...   ...  ...         ...       ...           ...
# 6921683  999998   917.21927     8  ...          12       0.0           0.0
# 6921684  999998  1709.49237     6  ...           6       0.0           0.0
# 6921685  999998  1765.54537     7  ...           4       0.6           1.0
# 6921686  999999   974.04976     0  ...          10      -0.1           0.6
# 6921687  999999  2674.38856     3  ...           8       0.8           0.7
#
# [6921688 rows x 7 columns]
